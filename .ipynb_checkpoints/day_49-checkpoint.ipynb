# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/Users/dileepsathyan/Documents/GitHub/datasets/ts_sales_data.csv')

# %%
df.head()
# Out:
#          date     value
# 0  1991-07-01  3.526591
# 1  1991-08-01  3.180891
# 2  1991-09-01  3.252221
# 3  1991-10-01  3.611003
# 4  1991-11-01  3.565869

# %%
df.columns = ['Date', 'Sales']
df.head()
# Out:
#          Date     Sales
# 0  1991-07-01  3.526591
# 1  1991-08-01  3.180891
# 2  1991-09-01  3.252221
# 3  1991-10-01  3.611003
# 4  1991-11-01  3.565869

# %%
df.shape
# Out:
# (204, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    204 non-null    object
#  1   Sales   204 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.3+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date     Sales
# 0 1991-07-01  3.526591
# 1 1991-08-01  3.180891
# 2 1991-09-01  3.252221
# 3 1991-10-01  3.611003
# 4 1991-11-01  3.565869

# %%
df = df.set_index('Date')
df.head()
# Out:
#                Sales
# Date
# 1991-07-01  3.526591
# 1991-08-01  3.180891
# 1991-09-01  3.252221
# 1991-10-01  3.611003
# 1991-11-01  3.565869

# %%
plt.figure(figsize=(10,5))
plt.plot(df.Sales)

# %%
df['Prev_Month_Sales'] = df['Sales'].shift(1)
df.head()
# Out:
#                Sales  Prev_Month_Sales
# Date
# 1991-07-01  3.526591               NaN
# 1991-08-01  3.180891          3.526591
# 1991-09-01  3.252221          3.180891
# 1991-10-01  3.611003          3.252221
# 1991-11-01  3.565869          3.611003

# %%
df['Diff_Sales'] = df['Prev_Month_Sales'] - df['Sales']
df.head()
# Out:
#                Sales  Prev_Month_Sales  Diff_Sales
# Date
# 1991-07-01  3.526591               NaN         NaN
# 1991-08-01  3.180891          3.526591    0.345700
# 1991-09-01  3.252221          3.180891   -0.071330
# 1991-10-01  3.611003          3.252221   -0.358782
# 1991-11-01  3.565869          3.611003    0.045134

# %%
fig = plt.figure(figsize=(10,5))
plt.plot(df[['Sales', 'Diff_Sales']])
# Out:
# [<matplotlib.lines.Line2D at 0x7ff15b3fe7f0>,
#  <matplotlib.lines.Line2D at 0x7ff15b9aec40>]

# %%
# Moving Averages over a window of 2 months

# %%
df['Rolling_Avg'] = df['Sales'].rolling(window=2).mean()
df.head()
# Out:
#                Sales  Prev_Month_Sales  Diff_Sales  Rolling_Avg
# Date
# 1991-07-01  3.526591               NaN         NaN          NaN
# 1991-08-01  3.180891          3.526591    0.345700     3.353741
# 1991-09-01  3.252221          3.180891   -0.071330     3.216556
# 1991-10-01  3.611003          3.252221   -0.358782     3.431612
# 1991-11-01  3.565869          3.611003    0.045134     3.588436

# %%
fig = plt.figure(figsize=(10,5))
plt.plot(df[['Sales', 'Rolling_Avg']])
# Out:
# [<matplotlib.lines.Line2D at 0x7ff15afdf490>,
#  <matplotlib.lines.Line2D at 0x7ff15afc5a60>]

# %%
# Zoom in to see how the SMA has smoothened the data.

fig = plt.figure(figsize=(10,5))
plt.plot(df[['Sales', 'Rolling_Avg']].head(50))
# Out:
# [<matplotlib.lines.Line2D at 0x7ff159f289a0>,
#  <matplotlib.lines.Line2D at 0x7ff15b5de9d0>]
