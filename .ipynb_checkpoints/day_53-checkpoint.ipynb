# %%
import numpy as np
import pandas as pd

# %%
df_raw = pd.read_csv('/Users/dileepsathyan/Documents/GitHub/datasets/ts_covid19_confirmed_global.csv')
df_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/18/20  7/19/20  7/20/20  \
# 0        0        0        0        0  ...    35301    35475    35526
# 1        0        0        0        0  ...     4008     4090     4171
# 2        0        0        0        0  ...    22549    23084    23691
# 3        0        0        0        0  ...      880      880      884
# 4        0        0        0        0  ...      687      705      749
#
#    7/21/20  7/22/20  7/23/20  7/24/20  7/25/20  7/26/20  7/27/20
# 0    35615    35727    35928    35981    36036    36157    36263
# 1     4290     4358     4466     4570     4637     4763     4880
# 2    24278    24872    25484    26159    26764    27357    27973
# 3      884      889      889      897      897      897      907
# 4      779      812      851      880      916      932      950
#
# [5 rows x 192 columns]

# %%
df_raw = df_raw.dropna(axis=1)
df_raw.shape
# Out:
# (266, 191)

# %%
# Remove the unnecessary columns (Lat and Long)

df_raw = df_raw.drop(columns=['Lat', 'Long'])
df_raw.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  7/18/20  7/19/20  7/20/20  7/21/20  \
# 0        0        0        0  ...    35301    35475    35526    35615
# 1        0        0        0  ...     4008     4090     4171     4290
# 2        0        0        0  ...    22549    23084    23691    24278
# 3        0        0        0  ...      880      880      884      884
# 4        0        0        0  ...      687      705      749      779
#
#    7/22/20  7/23/20  7/24/20  7/25/20  7/26/20  7/27/20
# 0    35727    35928    35981    36036    36157    36263
# 1     4358     4466     4570     4637     4763     4880
# 2    24872    25484    26159    26764    27357    27973
# 3      889      889      897      897      897      907
# 4      812      851      880      916      932      950
#
# [5 rows x 189 columns]

# %% [markdown]
# ## 1. Group by the country and sum the total counts in Descending order.

# %%
df1 = df_raw.copy()
df1['Row_Totals'] = df1.sum(axis=1)
df1.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  7/19/20  7/20/20  7/21/20  7/22/20  \
# 0        0        0        0  ...    35475    35526    35615    35727
# 1        0        0        0  ...     4090     4171     4290     4358
# 2        0        0        0  ...    23084    23691    24278    24872
# 3        0        0        0  ...      880      884      884      889
# 4        0        0        0  ...      705      749      779      812
#
#    7/23/20  7/24/20  7/25/20  7/26/20  7/27/20  Row_Totals
# 0    35928    35981    36036    36157    36263     1936390
# 1     4466     4570     4637     4763     4880      196702
# 2    25484    26159    26764    27357    27973     1179755
# 3      889      897      897      897      907       94404
# 4      851      880      916      932      950       22662
#
# [5 rows x 190 columns]

# %%
# Subset the dataframe to contain only relevant fields

df1 = df1[["Country/Region", "Row_Totals"]]
df1.head()
# Out:
#   Country/Region  Row_Totals
# 0    Afghanistan     1936390
# 1        Albania      196702
# 2        Algeria     1179755
# 3        Andorra       94404
# 4         Angola       22662

# %%
# Group by the country and find the totals

df2 = df1.groupby(['Country/Region']).sum()
df2 = df2.sort_values('Row_Totals', ascending=False)
df2
# Out:
#                        Row_Totals
# Country/Region
# US                      224345948
# Brazil                   89524967
# Russia                   45408411
# India                    40883464
# Spain                    27404045
# ...                           ...
# Saint Kitts and Nevis        1772
# Holy See                     1356
# Papua New Guinea             1185
# MS Zaandam                   1070
# Western Sahara                901
#
# [188 rows x 1 columns]
